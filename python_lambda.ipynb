# %% [markdown]
# In Python, anonymous function means that a function is without a name. As we already know that def keyword is used to define the normal functions and the lambda keyword is used to create anonymous functions. It has the following syntax:
#
# lambda arguments: expression
#
# This function can have any number of arguments but only one expression, which is evaluated and returned.
#
# One is free to use lambda functions wherever function objects are required.
# You need to keep in your knowledge that lambda functions are syntactically restricted to a single expression.
#
# It has various uses in particular fields of programming besides other types of expressions in functions.

# %%
# Python code to illustrate cube of a number  
# showing difference between def() and lambda(). 
def cube(y): 
    return y*y*y
  
g = lambda x: x*x*x 
print(g(7)) 
  
print(cube(5))
# Out:
# 343
# 125

# %%
g=lambda x,y:x+y
print(g(7,5))
# Out:
# 12

# %% [markdown]
# Without using Lambda : Here, both of them returns the cube of a given number. But, while using def, we needed to define a function with a name cube and needed to pass a value to it. After execution, we also needed to return the result from where the function was called using the return keyword.
#
# Using Lambda : Lambda definition does not include a “return” statement, it always contains an expression which is returned. We can also put a lambda definition anywhere a function is expected, and we don’t have to assign it to a variable at all. This is the simplicity of lambda functions.

# %% [markdown]
# The **filter()** function in Python takes in a function and a list as arguments. This offers an elegant way to filter out all the elements of a sequence “sequence”, for which the function returns True. Here is a small program that returns the odd numbers from an input list:

# %%
# Python code to illustrate 
# filter() with lambda() 
li = [5, 7, 22, 97, 54, 62, 77, 23, 73, 61] 
final_list = list(filter(lambda x: (x%2 != 0) , li)) 
print(final_list)
# Out:
# [5, 7, 97, 77, 23, 73, 61]

# %%
li = (5, 7, 22, 97, 54, 62, 77, 23, 73, 61)
final_t= tuple(filter(lambda x: (x%2 != 0) , li)) 
print(final_t)
# Out:
# (5, 7, 97, 77, 23, 73, 61)

# %%
li = {5, 7, 22, 97, 54, 62, 77, 23, 73, 61,5,5}
final_list = set(filter(lambda x: (x%2 != 0) , li)) 
print(final_list)
# Out:
# {97, 5, 7, 73, 77, 23, 61}

# %% [markdown]
# **Use of lambda() with map()**
#
# The map() function in Python takes in a function and a list as argument. The function is called with a lambda function and a list and a new list is returned which contains all the lambda modified items returned by that function for each item. Example:

# %%
# Python code to illustrate  
# map() with lambda()  
# to get double of a list. 
li = [5, 7, 22, 97, 54, 62, 77, 23, 73, 61] 
final_list = list(map(lambda x: x*2 , li)) 
print(final_list)
# Out:
# [10, 14, 44, 194, 108, 124, 154, 46, 146, 122]

# %%
li = (5, 7, 22, 97, 54, 62, 77, 23, 73, 61) 
final_list = tuple(map(lambda x: x*2 , li)) 
print(final_list)
# Out:
# (10, 14, 44, 194, 108, 124, 154, 46, 146, 122)

# %%
#add 2 numbers using lambda
adder = lambda x, y: x + y
print (adder (1, 2))
# Out:
# 3

# %%
#create a list and print values greater than 4 using lambda
sequences = [10,2,8,7,5,4,3,11,0, 1]
filtered_result = filter (lambda x: x > 4, sequences) 
print(list(filtered_result))
# Out:
# [10, 8, 7, 5, 11]

# %%
#multiply 2 elements
x = lambda a, b : a * b
print(x(5, 6))
# Out:
# 30

# %%
#add 3 numbers
x = lambda a, b, c : a + b + c
print(x(5, 6, 2))
# Out:
# 13

# %% [markdown]
# ** format() Function**
#
# The python format() function returns a formatted representation of the given value.
#
# **format(value, format)**
#
# **value**: It is the value that needs to be formatted.
#
# **format**: It is the specification on how the value should be formatted.

# %%
# Python3 program to demonstarte 
# the str.format() method 
  
# using format option in a simple string 
print ("{}, A computer science portal for students."
                        .format("wozti")) 
  
# using format option for a 
# value stored in a variable 
str = "This article is written in {}"
print (str.format("Python")) 
  
# formatting a string using a numeric constant 
print ("Hello, I am {} years old !".format(18))
# Out:
# wozti, A computer science portal for students.
# This article is written in Python
# Hello, I am 18 years old !

# %%
# default arguments
print("Hello {}, your balance is {}.".format("Adam", 230.2346))

# positional arguments
print("Hello {0}, your balance is {1}.".format("Adam", 230.2346))
print("Hello {1}, your balance is {0}.".format("Adam", 230.2346))
# keyword arguments
print("Hello {name}, your balance is {blc}.".format(name="Adam", blc=230.2346))

# mixed arguments
print("Hello {0}, your balance is {blc}.".format("Adam", blc=230.2346))
# Out:
# Hello Adam, your balance is 230.2346.
# Hello Adam, your balance is 230.2346.
# Hello 230.2346, your balance is Adam.
# Hello Adam, your balance is 230.2346.
# Hello Adam, your balance is 230.2346.

# %%
my_string = "{} is a science portal for {}"
  
print (my_string.format("GeeksforGeeks","hello","computer","hai"))
# Out:
# GeeksforGeeks is a science portal for hello

# %%
print ("This is {} {} {} {}"
       .format("one", "two", "three", "four"))
# Out:
# This is one two three four

# %%
my_string = "{}, is a {} science portal for {}"
print (my_string.format("GeeksforGeeks", "computer", "geeks"))
# Out:
# GeeksforGeeks, is a computer science portal for geeks

# %%
# octal, binary and hexadecimal format
print("bin: {1:b}, oct: {1:o}, hex: {1:x}".format(12,5))
# Out:
# bin: 101, oct: 5, hex: 5

# %%
print("The temperature today is {0:f} degrees outside !"
                                        .format(35))
# Out:
# The temperature today is 35.000000 degrees outside !

# %%
print ("This site is {0:f}% securely {1}!!". 
                    format(100, "encrypted")) 
  
# To limit the precision 
print ("My average of this {0} was {1:.2f}%"
            .format("semester", 78.234876)) 
  
# For no decimal places 
print ("My average of this {0} was {1:.0f}%"
            .format("semester", 78.234876)) 
  
# Convert an integer to its binary or 
# with other different converted bases. 
print("The {0} of 100 is {1:b}"
        .format("binary", 100)) 
          
print("The {1} of 100 is {0:o}"
        .format(100,"octal"))
# Out:
# This site is 100.000000% securely encrypted!!
# My average of this semester was 78.23%
# My average of this semester was 78%
# The binary of 100 is 1100100
# The octal of 100 is 144

# %%
print("{0:4}, is the computer science portal for {1:8}!"
                        .format("GeeksforGeeks", "geeks"))
# Out:
# GeeksforGeeks, is the computer science portal for geeks   !

# %%
print("It is {} degrees outside !"
                        .format(40))
print("It is {0:5} degrees outside !"
                        .format(40))
# Out:
# It is 40 degrees outside !
# It is    40 degrees outside !

# %%
print("{0:4} was founded in {1:16}!"
    .format("GeeksforGeeks", 2009)) 

print("{1:4} was founded in {0:16}!"
    .format("GeeksforGeeks", 2009))
# Out:
# GeeksforGeeks was founded in             2009!
# 2009 was founded in GeeksforGeeks   !

# %%
#date and time
import datetime

x = datetime.datetime.now()
print(x)
# Out:
# 2020-11-27 07:12:04.199198

# %%
import datetime

x = datetime.datetime(2020, 5, 17)

print(x)
# Out:
# 2020-05-17 00:00:00
