# %% [markdown]
# **Dictionary** in Python is an unordered collection of data values, used to store data values like a map, which unlike other Data Types that hold only single value as an element, Dictionary holds key:value pair.
#
# In Python, a Dictionary can be created by placing sequence of elements within curly {} braces, separated by ‘comma’. Dictionary holds a pair of values, one being the Key and the other corresponding pair element being its Key:value. Values in a dictionary can be of any datatype and can be duplicated, whereas keys can’t be repeated and must be immutable.

# %%
d = {1: 'a', 2: 'b', 3: 'c'} 
print("\nDictionary with the use of Integer Keys: ") 
print(d) 

# with Mixed keys 
d1 = {'Name': 'apple', 1: [1, 2, 3, 4]} 
print("\nDictionary with the use of Mixed Keys: ") 
print(d1)
# Out:
# Dictionary with the use of Integer Keys:
# {1: 'a', 2: 'b', 3: 'c'}
#
# Dictionary with the use of Mixed Keys:
# {'Name': 'apple', 1: [1, 2, 3, 4]}

# %%
# Creating an empty Dictionary 
Dict = {} 
print("Empty Dictionary: ") 
print(Dict) 
  
# Creating a Dictionary 
# with dict() method 
D = dict({1: 'hello', 2: 'all', 3:'goodmorning'}) 
print("\nDictionary with the use of dict(): ") 
print(D) 
  
# Creating a Dictionary 
# with each item as a Pair 
Dict = dict([(1, 'heii'), (2, 'all')]) 
print("\nDictionary with each item as a pair: ") 
print(Dict)
# Out:
# Empty Dictionary:
# {}
#
# Dictionary with the use of dict():
# {1: 'hello', 2: 'all', 3: 'goodmorning'}
#
# Dictionary with each item as a pair:
# {1: 'heii', 2: 'all'}

# %% [markdown]
# **Adding elements to a Dictionary**
#
# in Python Dictionary, Addition of elements can be done in multiple ways. One value at a time can be added to a Dictionary by defining value along with the key e.g. Dict[Key] = ‘Value’. Updating an existing value in a Dictionary can be done by using the built-in update() method. Nested key values can also be added to an existing Dictionary.
# Note- While adding a value, if the key value already exists, the value gets updated otherwise a new Key with the value is added to the Dictionary.

# %%
Dict = {} 
print("Empty Dictionary: ") 
print(Dict) 
  
# Adding elements one at a time 
Dict['fruit'] = 'apple'
Dict[2] = 'orange'
Dict[3] = 1
print("\nDictionary after adding 3 elements: ") 
print(Dict)
# Out:
# Empty Dictionary:
# {}
#
# Dictionary after adding 3 elements:
# {'fruit': 'apple', 2: 'orange', 3: 1}

# %%
# Adding set of values  
# to a single Key 
Dict['a'] = {2, 3, 4,4}
print("\nDictionary after adding 3 elements: ") 
print(Dict)
# Out:
# Dictionary after adding 3 elements:
# {'fruit': 'apple', 2: 'orange', 3: 1, 'a': {2, 3, 4}}

# %%
# Updating existing Key's Value 
Dict[2] = 'Welcome'
print("\nUpdated key value: ") 
print(Dict)
# Out:
# Updated key value:
# {'fruit': 'apple', 2: 'Welcome', 3: 1, 'Value_set': (2, 3, 4)}

# %% [markdown]
# **Accessing** elements from a **Dictionary**
# In order to access the items of a dictionary refer to its key name.Key can be used inside square brackets.

# %%
# accessing a element from a Dictionary  
  
# Creating a Dictionary  
D = {1: 'hello', 'name': 'everybody', 3: 'hai'} 
  
# accessing a element using key 
print("Accessing a element using key:") 
print(D['name']) 
  
# accessing a element using key 
print("Accessing a element using key:") 
print(D[1])
# Out:
# Accessing a element using key:
# everybody
# Accessing a element using key:
# hello

# %% [markdown]
# **Removing Elements from Dictionary**
#
# using **del**

# %%
Dict = { 5 : 'Welcome', 6 : 'To', 7 : 'kerala', 
        'A' : {1 : 'idukki', 2 : 'kottayam', 3 : 'palakkad'}, 
        'B' : {1 : 'mumbai', 2 : 'pune'}} 
print("Initial Dictionary: ") 
print(Dict) 
  
# Deleting a Key value 
del Dict['A'] 
print("\nDeleting a specific key: ") 
print(Dict)
# Out:
# Initial Dictionary:
# {5: 'Welcome', 6: 'To', 7: 'kerala', 'A': {1: 'idukki', 2: 'kottayam', 3: 'palakkad'}, 'B': {1: 'mumbai', 2: 'pune'}}
#
# Deleting a specific key:
# {5: 'Welcome', 6: 'To', 7: 'kerala', 'B': {1: 'mumbai', 2: 'pune'}}

# %%
del(Dict)
print(Dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-d40d16eb39a6> in <module>()
#       1 del(Dict)
# ----> 2 print(Dict)
#
# NameError: name 'Dict' is not defined

# %% [markdown]
# All the items from a dictionary can be deleted at once by using **clear()** method.

# %%
Dict = {1: 'hai', 'name':1.3, 3: 33} 
  
l=len(Dict)  
print(l)
# Deleting entire Dictionary 
Dict.clear() 
print("\nDeleting Entire Dictionary: ") 
print(Dict)
# Out:
# 3
#
# Deleting Entire Dictionary:
# {}

# %%
# Creating a Dictionary   
Dict = {1: 'JavaTpoint', 2: 'Peter', 3: 'Thomas'}   
# Deleting a key    
# using pop() method   
pop_ele = Dict.pop(3)   
print(Dict)
# Out:
# {1: 'JavaTpoint', 2: 'Peter'}

# %% [markdown]
# H.w
# find pop() and popitem()

# %%
# 16 looping
num= {1:123,2:456,3:4444,8:213}
                     
                    
                      
print('List Of given states:\n') 

  
# Iterating over keys 
for i in num: 
    print(i) 
    
print('values:\n')

# Iterating over values 
for j in num.values(): 
    print(j) 
#print both   
print('\n') 
for i,j in num.items(): 
    print(i, ":", j) 

    #values
for j in num: 
    print(num[j])
# Out:
# List Of given states:
#
# 1
# 2
# 3
# 8
# values:
#
# 123
# 456
# 4444
# 213
#
#
# 1 : 123
# 2 : 456
# 3 : 4444
# 8 : 213
# 123
# 456
# 4444
# 213

# %%
Employee={"Name":"John","Age":29,"Salary":25000,"Company":"GOOGLE","Name":"athira"}    
for x,y in Employee.items():    
    print(x,y)  
#In the dictionary, we cannot store multiple values for the same keys. If we pass more than one value for a single key, 
#then the value which is last assigned is considered as the value of the key.
# Out:
# Name athira
# Age 29
# Salary 25000
# Company GOOGLE

# %%
str(Employee)#It converts the dictionary into the printable string representation.
# Out:
# "{'Name': 'athira', 'Age': 29, 'Salary': 25000, 'Company': 'GOOGLE'}"

# %%
type(Employee['Age'])
#type(Employee['Company'])
#to get the value type
# Out:
# int

# %%
Employee = {"Name": "John", "Age": 29, "salary":25000,"Company":"GOOGLE",(12,3,45):"Department ID"}    
for x,y in Employee.items(): 
  print(x,y)    
#keys can't be mutable
# Out:
# Name John
# Age 29
# salary 25000
# Company GOOGLE
# (12, 3, 45) Department ID

# %%
Employee = {"Name": "John", "Age": 29, "salary":25000,"Company":"GOOGLE",{100,201,301}:"Department ID"}    
for x,y in Employee.items():    
    print(x,y)    
#list is also not allowed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-3558c5167414> in <module>()
# ----> 1 Employee = {"Name": "John", "Age": 29, "salary":25000,"Company":"GOOGLE",{100,201,301}:"Department ID"}
#       2 for x,y in Employee.items():
#       3     print(x,y)
#
# TypeError: unhashable type: 'set'

# %%
z=Employee.copy()#create a copy of dictionary
z
# Out:
# {'Age': 29, 'Company': 'GOOGLE', 'Name': 'athira', 'Salary': 25000}

# %%
Employee.keys()#print only the keys
# Out:
# dict_keys(['Name', 'Age', 'Salary', 'Company'])
